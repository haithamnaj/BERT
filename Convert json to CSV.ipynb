# %%
import json
import csv
 
 
# Opening JSON file and loading the data
# into the variable data
with open('CAT - Peoria v2.json') as json_file:
    data = json.load(json_file)

# %%
employee_data = data['features']
 
# now we will open a file for writing
data_file = open('data_file.csv', 'w')

# %%
csv_writer = csv.writer(data_file)
 
# Counter variable used for writing
# headers to the CSV file
count = 0
 
for emp in employee_data:
    if count == 0:
 
        # Writing headers of CSV file
        header = emp.keys()
        csv_writer.writerow(header)
        count += 1
 
    # Writing data of CSV file
    csv_writer.writerow(emp.values())
 
data_file.close()

# %%
csv_writer

# %%
import csv
import pandas as pd

# %%
json_csv = pd.read_csv("data_file.csv")
json_csv
# Out:
#         type                                         properties  \
# 0    Feature  {'category': 'Site', 'id': 'CATEP', 'name': 'C...
# 1    Feature  {'category': 'POI', 'id': 'BLCV', 'name': 'Bui...
# 2    Feature  {'category': 'Floor', 'id': 'BLCV_FL01', 'name...
# 3    Feature  {'category': 'Room', 'id': 'BLCV_RM01', 'name'...
# 4    Feature  {'category': 'Room', 'id': 'BLCV_RM02', 'name'...
# ..       ...                                                ...
# 632  Feature  {'category': 'Furniture', 'id': 'BLCV_FR02', '...
# 633  Feature  {'category': 'Furniture', 'id': 'BLCV_FR03', '...
# 634  Feature  {'category': 'Furniture', 'id': 'BLCV_FR04', '...
# 635  Feature  {'category': 'Furniture', 'id': 'BLCV_FR05', '...
# 636  Feature  {'category': 'Furniture', 'id': 'BLCV_FR06', '...
#
#                                               geometry
# 0    {'type': 'Polygon', 'coordinates': [[[-89.5931...
# 1    {'type': 'Polygon', 'coordinates': [[[-89.5899...
# ...

# %%
import pandas as pd
df = pd.read_json ('CAT - Peoria v2.json')
export_csv = df.to_csv ('new.csv', index = True, header=True)

# %%
json_csv1 = pd.read_csv("new.csv")
json_csv1
# Out:
#      Unnamed: 0               type  \
# 0             0  FeatureCollection
# 1             1  FeatureCollection
# 2             2  FeatureCollection
# 3             3  FeatureCollection
# 4             4  FeatureCollection
# ..          ...                ...
# 632         632  FeatureCollection
# 633         633  FeatureCollection
# 634         634  FeatureCollection
# 635         635  FeatureCollection
# 636         636  FeatureCollection
#
#                                               features
# 0    {'type': 'Feature', 'properties': {'category':...
# 1    {'type': 'Feature', 'properties': {'category':...
# 2    {'type': 'Feature', 'properties': {'category':...
# 3    {'type': 'Feature', 'properties': {'category':...
# 4    {'type': 'Feature', 'properties': {'category':...
# ..                                                 ...
# 632  {'type': 'Feature', 'properties': {'category':...
# 633  {'type': 'Feature', 'properties': {'category':...
# ...
